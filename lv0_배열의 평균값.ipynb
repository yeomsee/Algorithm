# %% [markdown]
# Q. 정수 배열 numbers가 매개변수로 주어집니다. numbers의 원소의 평균값을 return하도록 solution 함수를 완성해주세요.

# %% [markdown]
# # 나의 코드

# %%
def solution(number_list):
    sum = 0
    for number in number_list:
        sum += number
    answer = sum / len(number_list)

    return answer

# %% [markdown]
# ---

# %% [markdown]
# # Best 코드

# %%
def solution2(number_list):
    return sum(number_list) / len(number_list)

# %% [markdown]
# → 훨씬 깔끔하고 포기 좋은 듯!
